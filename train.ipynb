# %% [markdown]
# <a href="https://colab.research.google.com/github/jackkim-usd/AAI521-group4/blob/ahmed/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content')
# !pwd
# Out:
# /content

# %%
# !rm -rf data
# !mkdir -p data

# !unzip "Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network.zip" -d data
# Out:
# Archive:  Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network.zip
#   inflating: data/Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network/Plant_leaf_diseases_dataset_without_augmentation.zip
#   inflating: data/Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network/Plant_leaf_diseases_dataset_with_augmentation.zip

# %%
inner_dir = "data/Data for Identification of Plant Leaf Diseases Using a 9-layer Deep Convolutional Neural Network"

# !unzip -q "{inner_dir}/Plant_leaf_diseases_dataset_without_augmentation.zip" -d data/without_aug
# !unzip -q "{inner_dir}/Plant_leaf_diseases_dataset_with_augmentation.zip" -d data/with_aug

# %%
# !ls data/without_aug
# !ls data/with_aug
# Out:
# Plant_leave_diseases_dataset_without_augmentation
# Plant_leave_diseases_dataset_with_augmentation

# %%
# !ls data/without_aug/Plant_leave_diseases_dataset_without_augmentation
# Out:
#  Apple___Apple_scab
#  Apple___Black_rot
#  Apple___Cedar_apple_rust
#  Apple___healthy
#  Background_without_leaves
#  Blueberry___healthy
#  Cherry___healthy
#  Cherry___Powdery_mildew
# 'Corn___Cercospora_leaf_spot Gray_leaf_spot'
#  Corn___Common_rust
#  Corn___healthy
#  Corn___Northern_Leaf_Blight
#  Grape___Black_rot
# 'Grape___Esca_(Black_Measles)'
#  Grape___healthy
# 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'
# 'Orange___Haunglongbing_(Citrus_greening)'
#  Peach___Bacterial_spot
#  Peach___healthy
#  Pepper,_bell___Bacterial_spot
#  Pepper,_bell___healthy
#  Potato___Early_blight
#  Potato___healthy
#  Potato___Late_blight
#  Raspberry___healthy
#  Soybean___healthy
#  Squash___Powdery_mildew
#  Strawberry___healthy
#  Strawberry___Leaf_scorch
#  Tomato___Bacterial_spot
#  Tomato___Early_blight
#  Tomato___healthy
#  Tomato___Late_blight
#  Tomato___Leaf_Mold
#  Tomato___Septoria_leaf_spot
# 'Tomato___Spider_mites Two-spotted_spider_mite'
#  Tomato___Target_Spot
#  Tomato___Tomato_mosaic_virus
#  Tomato___Tomato_Yellow_Leaf_Curl_Virus

# %%
from importlib import reload
import utils.load_data as ld
reload(ld)

from utils.load_data import load_dataset

# %%
dataset_root = "data/without_aug/Plant_leave_diseases_dataset_without_augmentation"
train_ds, val_ds, class_names = load_dataset(dataset_root)

print("Total classes:", len(class_names))
print(class_names)
# Out:
# Found 55448 files belonging to 39 classes.
# Using 44359 files for training.
# Found 55448 files belonging to 39 classes.
# Using 11089 files for validation.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2096862488.py in <cell line: 0>()
#       1 dataset_root = "data/without_aug/Plant_leave_diseases_dataset_without_augmentation"
# ----> 2 train_ds, val_ds, class_names = load_dataset(dataset_root)
#       3
#       4 print("Total classes:", len(class_names))
#       5 print(class_names)
#
# /content/utils/load_data.py in load_dataset(data_dir, img_size, batch_size, seed)
#      36     val_ds = val_ds.map(preprocess).prefetch(AUTOTUNE)
#      37
# ---> 38     return train_ds, val_ds, train_ds.class_names
#
# AttributeError: '_PrefetchDataset' object has no attribute 'class_names'

# %%
# from utils.load_data import load_dataset
# train_ds, val_ds, class_names = load_dataset("data/without_aug")
# print(class_names)

from utils.load_data import load_dataset

dataset_root = "data/without_aug/Plant_leave_diseases_dataset_without_augmentation"
train_ds, val_ds, class_names = load_dataset(dataset_root)
print(class_names)
# Out:
# Found 55448 files belonging to 39 classes.
# Using 44359 files for training.
# Found 55448 files belonging to 39 classes.
# Using 11089 files for validation.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1241293788.py in <cell line: 0>()
#       6
#       7 dataset_root = "data/without_aug/Plant_leave_diseases_dataset_without_augmentation"
# ----> 8 train_ds, val_ds, class_names = load_dataset(dataset_root)
#       9 print(class_names)
#
# /content/utils/load_data.py in load_dataset(data_dir, img_size, batch_size, seed)
#      36     val_ds = val_ds.map(preprocess).prefetch(AUTOTUNE)
#      37
# ---> 38     return train_ds, val_ds, train_ds.class_names
#
# AttributeError: '_PrefetchDataset' object has no attribute 'class_names'

# %%
from models.inceptionv3_model import build_inceptionv3
# from models.resnet50_model import build_resnet50
# from models.efficientnet_model import build_efficientnet

# %%
from utils.train_utils import train_model, plot_history

# %%
model = build_inceptionv3(len(class_names))
history = train_model(model, train_ds, val_ds, epochs=10)
plot_history(history, "InceptionV3")

# %%
# !ls data
# !ls -R data | head -100

# %%
# !ls data

# %%
# !ls -R data

# %%
# !ls -R

# %%
from utils.load_data import load_dataset
# from utils.train_utils import train_model, plot_history

# from models.inceptionv3_model import build_inceptionv3
